# %%
import sys
sys.path.insert(0,'/Users/alexandra/Documents/master_thesis')

"""
Magic commands
"""

"""
Magic commands
"""

# %load_ext autoreload
# %autoreload 2

"""
Load relevant packages
"""

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import pandas_datareader as pdr
from pandas_datareader.yahoo.daily import YahooDailyReader


import datetime

"""
Load own functions/packages
"""

# set plotting style

from codelib.visualization.layout import DefaultStyle
DefaultStyle();
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
etf_list = pd.read_csv("/Users/alexandra/Documents/master_thesis/sb_etfs.csv")


etf_list
# Out:
#     Ticker
# 0     SPDV
# 1     DMDV
# 2     EEMD
# 3     WLDR
# 4     DIVA
# ..     ...
# 393   QARP
# 394   DEUS
# 395   SSPY
# 396   SSPY
# 397   SSPY
#
# [398 rows x 1 columns]

# %%
"""
Get adjusted stock prices for SB ETFs.
"""

tickers = list(etf_list['Ticker'])
etfs = YahooDailyReader(tickers, start=datetime.date(2007, 2, 23),interval='m').read()

"""
Get adjusted close and normalize
"""
etfs_adj_close = etfs['Adj Close']
etfs_adj_close
# Out:
# Symbols      SPDV   DMDV       EEMD       WLDR       DIVA       EDOG  \
# Date
# 2007-02-01    NaN    NaN        NaN        NaN        NaN        NaN
# 2007-03-01    NaN    NaN        NaN        NaN        NaN        NaN
# 2007-04-01    NaN    NaN        NaN        NaN        NaN        NaN
# 2007-05-01    NaN    NaN        NaN        NaN        NaN        NaN
# 2007-06-01    NaN    NaN        NaN        NaN        NaN        NaN
# ...           ...    ...        ...        ...        ...        ...
# 2022-02-17    NaN    NaN        NaN        NaN        NaN        NaN
# 2022-02-18    NaN    NaN        NaN        NaN        NaN        NaN
# 2022-02-22    NaN    NaN        NaN        NaN        NaN        NaN
# 2022-02-23    NaN    NaN        NaN        NaN        NaN        NaN
# 2022-02-24  30.01  23.08  21.049999  24.860001  25.200001  23.639999
#
# Symbols          IDOG       RDOG       SDOG     QINT  ...       USMF  \
# Date                                                  ...
# ...

# %%
etfs_adj_close.to_csv("/Users/alexandra/Documents/master_thesis/etfs_prices.csv")
