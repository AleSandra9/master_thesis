# %%
import sys
sys.path.insert(0,'/Users/alexandra/Documents/master_thesis')

"""
Magic commands
"""

# %load_ext autoreload
# %autoreload 2

"""
Load relevant packages
"""

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import pandas_datareader as pdr
from pandas_datareader.yahoo.daily import YahooDailyReader


import datetime

"""
Load own functions/packages
"""

# set plotting style

from codelib.visualization.layout import DefaultStyle
DefaultStyle();
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
'''Import MSCI indices'''

msci = pd.read_csv("/Users/alexandra/Documents/master_thesis/msci.csv",index_col='Date',parse_dates=True)

msci
# Out:
#             MSCI US Minimum Volatility   MSCI US  MSCI US Momentum  \
# Date
# 1994-06-30                     419.991   414.388           154.736
# 1994-07-29                     430.102   427.442           159.462
# 1994-08-31                     442.821   443.324           166.509
# 1994-09-30                     438.976   433.000           161.408
# 1994-10-31                     440.705   442.000           164.207
# ...                                ...       ...               ...
# 2021-10-29                    3643.382  4475.121          4119.983
# 2021-11-30                    3566.693  4424.065          3954.608
# 2021-12-31                    3802.744  4593.595          3931.368
# 2022-01-31                    3574.679  4329.863          3572.491
# 2022-02-28                    3461.107  4196.992          3473.808
#
#             MSCI US Quality  MSCI US High Dividend Yield  MSCI US Value  \
# Date
# 1994-06-30          209.467                      406.212        592.169
# 1994-07-29          214.238                      416.972        610.769
# 1994-08-31          226.912                      428.839        626.936
# 1994-09-30          224.901                      419.767        603.990
# 1994-10-31          232.265                      425.403        617.713
# ...                     ...                          ...            ...
# 2021-10-29         3942.065                     2590.819       3387.021
# 2021-11-30         3932.813                     2545.847       3288.414
# 2021-12-31         4085.888                     2730.740       3506.952
# 2022-01-31         3779.013                     2669.812       3415.955
# 2022-02-28         3579.589                     2608.463       3345.740
#
#             MSCI US Small Cap  MSCI US Equal Weight
# Date
# 1994-06-30             67.819               438.422
# 1994-07-29             69.265               453.331
# 1994-08-31             73.727               473.073
# 1994-09-30             72.533               460.635
# 1994-10-31             72.596               465.615
# ...                       ...                   ...
# 2021-10-29           1018.327              5486.150
# 2021-11-30            973.331              5314.739
# 2021-12-31           1004.856              5553.091
# 2022-01-31            923.696              5222.916
# 2022-02-28            932.005              5151.869
#
# [333 rows x 8 columns]

# %%
'''Resample'''
msci=msci[(msci.index>='2002-12-29')&(msci.index.year<2022)]
msci
# Out:
#             MSCI US Minimum Volatility   MSCI US  MSCI US Momentum  \
# Date
# 2002-12-31                     790.173   824.583           496.527
# 2003-01-31                     762.986   803.601           487.191
# 2003-02-28                     743.769   789.797           482.339
# 2003-03-31                     748.679   796.075           486.858
# 2003-04-30                     798.431   861.537           516.031
# ...                                ...       ...               ...
# 2021-08-31                    3643.963  4399.110          3937.535
# 2021-09-30                    3457.481  4186.849          3797.672
# 2021-10-29                    3643.382  4475.121          4119.983
# 2021-11-30                    3566.693  4424.065          3954.608
# 2021-12-31                    3802.744  4593.595          3931.368
# 2021-11-30           6.954898              6.197390
# 2021-12-31           7.180158              6.475326
#
# [229 rows x 8 columns]

# %%
'''Calculate relative performance to MSCI US'''
msci_relative_performance=msci_normalized.iloc[:].div(msci_normalized['MSCI US'],axis=0)*100
msci_relative_performance
# Out:
#             MSCI US Minimum Volatility  MSCI US  MSCI US Momentum  \
# Date
# 2002-12-31                  100.000000    100.0        100.000000
# 2003-01-31                   99.080523    100.0        100.681643
# 2003-02-28                   98.273129    100.0        101.421121
# 2003-03-31                   98.141763    100.0        101.564008
# 2003-04-30                   96.710950    100.0         99.470286
# ...                                ...      ...               ...
# 2021-08-31                   86.441308    100.0        148.645276
# 2021-09-30                   86.175675    100.0        150.633533
# 2021-10-29                   84.959533    100.0        152.891080
# 2021-11-30                   84.131072    100.0        148.447692
# 2021-12-31                   86.388628    100.0        142.128936
#
#             MSCI US Quality  MSCI US High Dividend Yield  MSCI US Value  \
# Date
# 2002-12-31       100.000000                   100.000000     100.000000
# 2003-01-31        99.269100                    99.525227     100.343276
# 2003-02-28        99.784983                    98.515072      99.349303
# 2003-03-31       100.274992                    98.358864      97.975107
# 2003-04-30        98.228942                    98.690031      99.870515
# ...                     ...                          ...            ...
# 2021-08-31       126.910279                    64.143697      61.613389
# 2021-09-30       124.725227                    63.980869      62.266901
# 2021-10-29       124.731675                    62.013376      61.480376
# 2021-11-30       125.875020                    61.640178      60.379345
# 2021-12-31       125.948068                    63.676727      62.015540
#
#             MSCI US Small Cap  MSCI US Equal Weight
# Date
# 2002-12-31         100.000000            100.000000
# 2003-01-31         100.005195            100.416456
# 2003-02-28          98.837639             99.761735
# 2003-03-31          99.289770             99.441460
# 2003-04-30         102.155734            100.643449
# ...                       ...                   ...
# 2021-08-31         134.339096            118.612200
# 2021-09-30         136.904385            119.225317
# 2021-10-29         134.074768            117.875663
# 2021-11-30         129.629437            115.510561
# 2021-12-31         128.888956            116.236718
#
# [229 rows x 8 columns]

# %%
'''Plot the relative performance'''

years=msci_relative_performance.index
labels = ['MSCI US Minimum Volatility','MSCI US Momentum','MSCI US Quality','MSCI US High Dividend Yield','MSCI US Value','MSCI US Small Cap','MSCI US Equal Weight']
font = {'fontname':'Times New Roman'}

fig, ax = plt.subplots(figsize=(15, 8))
ax.set_xlabel('Year', fontsize = 20,**font);
ax.set_ylabel('Cumulative return relative to MSCI US', fontsize = 20,**font);
ax.set_title("Asset prices", fontsize = 30, **font);
ax.set_ylim([40,200])
ax = plt.plot(years, np.array(msci_relative_performance.iloc[:,[0,2,3,4,5,6,7]]), linewidth = 2.5)
plt.grid(color = "gray", linestyle = "--")
plt.legend(iter(ax), labels,loc='center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=3)
ax = plt.plot(years, np.array(msci_relative_performance.iloc[:,[1]]), linewidth = 1.0, linestyle='--')
