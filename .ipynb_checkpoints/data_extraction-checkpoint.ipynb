# %%
import sys
sys.path.insert(0,'/Users/alexandra/Documents/master_thesis')

"""
Magic commands
"""

# %load_ext autoreload
# %autoreload 2

"""
Load relevant packages
"""

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import pandas_datareader as pdr
from pandas_datareader.yahoo.daily import YahooDailyReader


import datetime

"""
Load own functions/packages
"""

# set plotting style

from codelib.visualization.layout import DefaultStyle
DefaultStyle();

# %%
'''Import ticker list'''

etf_list = pd.read_csv("/Users/alexandra/Documents/master_thesis/sb_etfs.csv")

etf_list
# Out:
#     Ticker
# 0     SPDV
# 1     SDOG
# 2     VALQ
# 3     BFOR
# 4     ESGS
# ..     ...
# 238    EES
# 239   DGRS
# 240    DTD
# 241   QARP
# 242   DEUS
#
# [243 rows x 1 columns]

# %%
"""
Get adjusted stock prices for SB ETFs.
"""

tickers = list(etf_list['Ticker'])
etfs = YahooDailyReader(tickers, start=datetime.date(2002, 12, 1),interval='d').read()

"""
Get adjusted close
"""
etfs_adj_close = etfs['Adj Close']
etfs_adj_close
